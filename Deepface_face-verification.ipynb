# %%
import numpy as np 
import cv2
import  matplotlib.pyplot  as plt

# %% [markdown]
# Deepface is a lightweight face recognition and facial attribute analysis (age, gender,emotion and race) framework for python. It is a hybrid face recognition framework wrapping state-of-the-art models: VGG-Face, Google FaceNet, OpenFace, Facebook DeepFace, DeepID, ArcFace, Dlib, SFace and GhostFaceNet .

# %%
from deepface import DeepFace
# Out:
# 24-07-07 09:59:38 - Directory C:\Users\bigya/.deepface/weights created

# %%
image_path1 = 'E:\\Computer-Vision\\OCR_project\\data\\raw_images\\women_face1.jpg'
image_path2 = 'E:\\Computer-Vision\\OCR_project\\data\\raw_images\\women_face2.jpg'

img1 = cv2.imread(image_path1)
img2 = cv2.imread(image_path2)

plt.imshow(img1)
plt.show()

plt.imshow(img2)
plt.show()

# %%
import os 
os.environ['DEEPFACE_HOME'] = 'E:/DeepFace'

# %%
verification = DeepFace.verify(img1_path= image_path1, img2_path= image_path2)
# Out:
# 24-07-07 10:05:12 - vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: E:\DeepFace\.deepface\weights\vgg_face_weights.h5
# 100%|██████████| 580M/580M [03:00<00:00, 3.22MB/s]

# %%
verification
# Out:
# {'verified': True,
#  'distance': 0.5386956404673018,
#  'threshold': 0.68,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 67,
#    'y': 52,
#    'w': 130,
#    'h': 130,
#    'left_eye': (155, 103),
#    'right_eye': (108, 101)},
#   'img2': {'x': 62,
#    'y': 54,
#    'w': 126,
#    'h': 126,
#    'left_eye': (148, 106),
#    'right_eye': (98, 102)}},
#  'time': 185.19}

# %%
verification['facial_areas']['img1']
# Out:
# {'x': 67,
#  'y': 52,
#  'w': 130,
#  'h': 130,
#  'left_eye': (155, 103),
#  'right_eye': (108, 101)}
